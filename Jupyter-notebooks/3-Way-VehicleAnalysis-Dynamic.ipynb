# %%
import random
import math
import time
import threading
import os
import pygame
import sys
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
header = ['P1', 'P2', 'P3','Lane1','Lane2','Lane3','Total']
with open('3-Way-Analysis-Dynamic.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    
    # write the header
    writer.writerow(header)

# %%
# Default values of signal times
defaultRed = 130
defaultYellow = 5
defaultGreen = 20
defaultMinimum = 10
defaultMaximum = 60

data = []
signals = []
noOfSignals = 3
simTime = 300       # total simulation time
timeElapsed = 0

# %%
currentGreen = 0   # Indicates which signal is green

nextGreen = (currentGreen+1)%noOfSignals

currentYellow = 0   # Indicates whether yellow signal is on or off 


# Average times for vehicles to pass the intersection
carTime = 2
bikeTime = 1
rickshawTime = 2.5
busTime = 3
truckTime = 3

# %%
# Count of vehicles at a traffic signal
noOfCars = 0
noOfBikes = 0
noOfBuses =0
noOfTrucks = 0
noOfRickshaws = 0
noOfLanes = 1

# %%
# Red signal time at which vehicles will be detected at a signal (when detection will start running)
detectionTime = 5

speeds = {'car':0.3375, 'bus':0.27, 'truck':0.27, 'rickshaw':0.3, 'bike':0.375}  # average speeds of vehicles

# %%
# Coordinates of start
x = {'right':[0,0], 'down':[740,706], 'left':[1400,1400]}    
y = {'right':[360,395], 'down':[0,0], 'left':[479,439]}


# Coordinates of signal image, timer, and vehicle count
signalCoods = [(530,230),(810,230),(810,570)]
signalTimerCoods = [(530,210),(810,210),(810,550)]
vehicleCountCoods = [(480,210),(880,210),(880,550)]
vehicleCountTexts = ["0", "0", "0"]



# Coordinates of stop lines
stopLines = {'right': 590, 'down': 330, 'left': 800}
defaultStop = {'right': 580, 'down': 320, 'left': 810}
stops = {'right': [580,580], 'down': [320,320], 'left': [810,810]}


mid = {'right': {'x':720, 'y':445}, 'down': {'x':695, 'y':460}, 'left': {'x':670, 'y':425}}
rotationAngle = 3

# Gap between vehicles
stoppingGap = 25    # stopping gap

movingGap = 25   # moving gap

# %%
vehicles = {'right': {0:[], 1:[], 'crossed':0}, 'down': {0:[], 1:[], 'crossed':0}, 'left': {0:[], 1:[], 'crossed':0}}

vehicleTypes = {0:'car', 1:'bus', 2:'truck', 3:'rickshaw', 4:'bike'}

directionNumbers = {0:'right', 1:'down', 2:'left'}

# %%
pygame.init()

simulation = pygame.sprite.Group()

# %%
class TrafficSignal:
    def __init__(self, red, yellow, green, minimum = 0, maximum = 0):
        self.red = red
        self.yellow = yellow
        self.green = green
        self.minimum = minimum
        self.maximum = maximum
        self.totalGreenTime = 0
        self.signalText = "--"

# %%
class Vehicle(pygame.sprite.Sprite):
    
    def __init__(self, lane,vehicleClass, direction_number, direction,will_turn):
        pygame.sprite.Sprite.__init__(self)
        self.lane = lane
        self.vehicleClass = vehicleClass
        self.speed = speeds[vehicleClass]
        self.x = x[direction][lane]
        self.y = y[direction][lane]
        self.direction_number = direction_number
        self.direction = direction
        self.crossed = 0
        self.willTurn = will_turn
        self.turned = 0
        self.rotateAngle = 0
        vehicles[direction][lane].append(self)
        self.index = len(vehicles[direction][lane]) - 1
        path = "images/" + direction + "/" + vehicleClass + ".png"
        self.originalImage = pygame.image.load(path)
        self.currentImage = pygame.image.load(path)
        
        
        
        if(direction=='right'):
            
            if(len(vehicles[direction][lane])>1 and vehicles[direction][lane][self.index-1].crossed==0):    # if more than 1 vehicle in the lane of vehicle before it has crossed stop line
                self.stop = vehicles[direction][lane][self.index-1].stop - vehicles[direction][lane][self.index-1].currentImage.get_rect().width - stoppingGap         # setting stop coordinate as: stop coordinate of next vehicle - width of next vehicle - gap
            
            else:
                
                self.stop = defaultStop[direction]
                
            # Set new starting and stopping coordinate
            temp = self.currentImage.get_rect().width + stoppingGap    
            x[direction][lane] -= temp
            stops[direction][lane] -= temp
            
            
        elif(direction=='left'):
            
            if(len(vehicles[direction][lane])>1 and vehicles[direction][lane][self.index-1].crossed==0):
                self.stop = vehicles[direction][lane][self.index-1].stop + vehicles[direction][lane][self.index-1].currentImage.get_rect().width + stoppingGap
            
            else:
                self.stop = defaultStop[direction]
                
            temp = self.currentImage.get_rect().width + stoppingGap  
            x[direction][lane] += temp
            stops[direction][lane] += temp
            
            
        elif(direction=='down'):
            
            if(len(vehicles[direction][lane])>1 and vehicles[direction][lane][self.index-1].crossed==0):
                self.stop = vehicles[direction][lane][self.index-1].stop - vehicles[direction][lane][self.index-1].currentImage.get_rect().height - stoppingGap
            
            else:
                self.stop = defaultStop[direction]
                
            temp = self.currentImage.get_rect().height + stoppingGap  
            y[direction][lane] -= temp
            stops[direction][lane] -= temp
            
        simulation.add(self)
        
        
    def render(self, screen):
        screen.blit(self.image, (self.x, self.y))
        
    
    def move(self):
        
        if(self.direction=='right'):
            
            if(self.crossed==0 and self.x+self.currentImage.get_rect().width>stopLines[self.direction]):   # if the image has crossed stop lines
                
                self.crossed = 1
                vehicles[self.direction]['crossed'] += 1
                
            if(self.willTurn==1):
                
                if(self.lane == 0):
                    
                    if(self.crossed==0 or self.x+self.currentImage.get_rect().width<stopLines[self.direction] + 40):

                        if((self.x+self.currentImage.get_rect().width<=self.stop or 
                            (currentGreen==0 and currentYellow==0) or self.crossed==1) and 
                           (self.index==0 or self.x+self.currentImage.get_rect().width<(vehicles[self.direction][self.lane][self.index-1].x - movingGap) 
                            or vehicles[self.direction][self.lane][self.index-1].turned==1)):                

                            self.x += self.speed

                    else:   

                        if(self.turned==0):
                            self.rotateAngle += rotationAngle
                            self.currentImage = pygame.transform.rotate(self.originalImage, self.rotateAngle)
                            self.x += 1.2
                            self.y -= 1.4
                            if(self.rotateAngle==90):
                                self.turned = 1

                        else:
                            if(self.index==0 or self.y-self.currentImage.get_rect().height
                               >(vehicles[self.direction][self.lane][self.index-1].y + movingGap) 
                               or self.x+self.currentImage.get_rect().width
                               <(vehicles[self.direction][self.lane][self.index-1].x - movingGap)):

                                self.y -= self.speed
                            
            else: 
                if((self.x+self.currentImage.get_rect().width<=self.stop or self.crossed == 1 or 
                    (currentGreen==0 and currentYellow==0)) and (self.index==0 or 
                     self.x+self.currentImage.get_rect().width
                    <(vehicles[self.direction][self.lane][self.index-1].x - movingGap) 
                     or (vehicles[self.direction][self.lane][self.index-1].turned==1))):    
                    
                # (if the image has not reached its stop coordinate or has crossed stop line or has green signal) and (it is either the first vehicle in that lane or it is has enough gap to the next vehicle in that lane)
                    self.x += self.speed  # move the vehicle



        elif(self.direction=='down'):
            
            if(self.crossed==0 and self.y+self.currentImage.get_rect().height>stopLines[self.direction]):
                self.crossed = 1
                vehicles[self.direction]['crossed'] += 1
                
            if(self.willTurn==1):
                
                if(self.lane == 0):
                    
                    if(self.crossed==0 or self.y+self.currentImage.get_rect().height< stopLines[self.direction] + 50):

                        if((self.y+self.currentImage.get_rect().height<=self.stop 
                            or (currentGreen==1 and currentYellow==0) or self.crossed==1) 
                           and (self.index==0 or self.y+self.currentImage.get_rect().height
                           <(vehicles[self.direction][self.lane][self.index-1].y - movingGap) 
                            or vehicles[self.direction][self.lane][self.index-1].turned==1)):   

                            self.y += self.speed

                    else:   
                        if(self.turned==0):
                            self.rotateAngle += rotationAngle
                            self.currentImage = pygame.transform.rotate(self.originalImage, self.rotateAngle)
                            self.x += 0.6
                            self.y += 0.9
                            if(self.rotateAngle==90):
                                self.turned = 1

                        else:
                            if(self.index==0 or 
                               self.x + vehicles[self.direction][self.lane][self.index-1].currentImage.get_rect().width < (vehicles[self.direction][self.lane][self.index-1].x - movingGap)
                               or self.y <(vehicles[self.direction][self.lane][self.index-1].y - movingGap)):
                                self.x += self.speed
                
                elif(self.lane == 1):
                    
                    if(self.crossed==0 or self.y+self.currentImage.get_rect().height<mid[self.direction]['y']):

                        if((self.y+self.currentImage.get_rect().height<=self.stop 
                            or (currentGreen==1 and currentYellow==0) or self.crossed==1) 
                           and (self.index==0 or self.y+self.currentImage.get_rect().height
                           <(vehicles[self.direction][self.lane][self.index-1].y - movingGap) 
                            or vehicles[self.direction][self.lane][self.index-1].turned==1)):   

                            self.y += self.speed

                    else:   
                        if(self.turned==0):
                            self.rotateAngle += rotationAngle
                            self.currentImage = pygame.transform.rotate(self.originalImage, -self.rotateAngle)
                            self.x -= 1.25
                            self.y += 1
                            if(self.rotateAngle==90):
                                self.turned = 1

                        else:
                            if(self.index==0 or 
                               self.x- vehicles[self.direction][self.lane][self.index-1].currentImage.get_rect().width > (vehicles[self.direction][self.lane][self.index-1].x + movingGap)
                               or self.y <(vehicles[self.direction][self.lane][self.index-1].y - movingGap)):
                                self.x -= self.speed
                            

        elif(self.direction=='left'):
            
            if(self.crossed==0 and self.x <stopLines[self.direction]):
                self.crossed = 1
                vehicles[self.direction]['crossed'] += 1
                
            if(self.willTurn==1):
                
                 if(self.lane == 1):
                    
                    if(self.crossed==0 or self.x> mid[self.direction]['x']):
                        if((self.x >= self.stop or (currentGreen==2 and currentYellow==0) or self.crossed==1) 
                           and (self.index==0 or self.x - vehicles[self.direction][self.lane][self.index-1].currentImage.get_rect().width>(vehicles[self.direction][self.lane][self.index-1].x + movingGap) 
                                or vehicles[self.direction][self.lane][self.index-1].turned==1)):     
                            self.x -= self.speed

                    else: 
                        if(self.turned==0):
                            self.rotateAngle += rotationAngle
                            self.currentImage = pygame.transform.rotate(self.originalImage, -self.rotateAngle)
                            self.x -= 0.9
                            self.y -= 1.25
                            if(self.rotateAngle==90):
                                self.turned = 1

                        else:
                            if(self.index==0 or 
                               self.y - vehicles[self.direction][self.lane][self.index-1].currentImage.get_rect().height>(vehicles[self.direction][self.lane][self.index-1].y  +  movingGap) 
                               or self.x > (vehicles[self.direction][self.lane][self.index-1].x + movingGap)):

                                self.y -= self.speed
                            
            else: 
                if((self.x >=self.stop or self.crossed == 1 or (currentGreen==2 and currentYellow==0)) 
                   and (self.index==0 or self.x - vehicles[self.direction][self.lane][self.index-1].currentImage.get_rect().width>(vehicles[self.direction][self.lane][self.index-1].x  + movingGap) 
                        or (vehicles[self.direction][self.lane][self.index-1].turned==1))):      
                    
                # (if the image has not reached its stop coordinate or has crossed stop line or has green signal) and (it is either the first vehicle in that lane or it is has enough gap to the next vehicle in that lane)
                    self.x -= self.speed  # move the vehicle

# %%
# Initialization of signals with default values
def initialize():
    
    ts1 = TrafficSignal(0, defaultYellow, defaultMaximum,
                        defaultMinimum, defaultMaximum)
    signals.append(ts1)
    ts2 = TrafficSignal(ts1.red+ts1.yellow+ts1.green, defaultYellow,
                        defaultMaximum, defaultMinimum, defaultMaximum)
    signals.append(ts2)
    ts3 = TrafficSignal(130, defaultYellow,
                        defaultMaximum, defaultMinimum, defaultMaximum)
    signals.append(ts3)

    repeat()

# %%
def setTime():
    
    
    global noOfCars, noOfBikes, noOfBuses, noOfTrucks, noOfRickshaws, noOfLanes
    global carTime, busTime, truckTime, rickshawTime, bikeTime

    noOfCars, noOfBuses, noOfTrucks, noOfRickshaws, noOfBikes = 0, 0, 0, 0, 0
    
    for i in range(0,2):
        
        for j in range(len(vehicles[directionNumbers[nextGreen]][i])):

            vehicle = vehicles[directionNumbers[nextGreen]][i][j]
            
            if(vehicle.crossed == 0):
                vclass = vehicle.vehicleClass

                if(vclass == 'car'):
                    noOfCars += 1
                elif(vclass == 'bus'):
                    noOfBuses += 1
                elif(vclass == 'truck'):
                    noOfTrucks += 1
                elif(vclass == 'rickshaw'):
                    noOfRickshaws += 1
                elif(vclass == 'bike'):
                    noOfBikes += 1
    

    greenTime = math.ceil(((noOfCars*carTime) + (noOfRickshaws*rickshawTime) + (
        noOfBuses*busTime) + (noOfTrucks*truckTime) + (noOfBikes*bikeTime))/(noOfLanes+1))
  
    print('Green Time: ', greenTime)
    if(greenTime < defaultMinimum):
        greenTime = defaultMinimum
    elif(greenTime > defaultMaximum):
        greenTime = defaultMaximum
   
    signals[(nextGreen) % (noOfSignals)].green = greenTime
    buffer = defaultMaximum - greenTime
    
    signals[(nextGreen + 1) % (noOfSignals)].red -= buffer

# %%
def repeat():
    
    
    global currentGreen, currentYellow, nextGreen
    # while the timer of current green signal is not zero
    
    while(signals[currentGreen].green > 0):
        printStatus()
        updateValues()
        
#         set time of next green signal
        if(signals[(currentGreen+1) % (noOfSignals)].red == detectionTime):
            
            thread = threading.Thread(
                name="detection", target=setTime, args=())
            thread.daemon = True
            thread.start()
            
        time.sleep(1)
        
    currentYellow = 1   # set yellow signal on
    
    for i in range(0,2):
        stops[directionNumbers[currentGreen]][i] = defaultStop[directionNumbers[currentGreen]]
        for vehicle in vehicles[directionNumbers[currentGreen]][i]:
            vehicle.stop = defaultStop[directionNumbers[currentGreen]]
    
    # while the timer of current yellow signal is not zero
    while(signals[currentGreen].yellow > 0):
        printStatus()
        updateValues()
        time.sleep(1)
    currentYellow = 0   # set yellow signal off

    # reset all signal times of current signal to default times
    signals[currentGreen].green = defaultGreen
    signals[currentGreen].yellow = defaultYellow
    signals[currentGreen].red = defaultRed
    
#     signals[currentGreen].green = 60
#     signals[currentGreen].yellow = 5
#     signals[currentGreen].red = 195

    
    currentGreen = nextGreen  # set next signal as green signal
    nextGreen = (currentGreen+1) % noOfSignals    # set next green signal
    
    #set the red time of next to next signal as (yellow time + green time) of next signal
    temp = signals[nextGreen].red
    signals[nextGreen].red = signals[currentGreen].yellow + signals[currentGreen].green
    
    # checking if the current red timer exceeds the previous ongoing timer or not
    if(signals[nextGreen].red > temp):
        print("I will go crazy...!")
        
    repeat()

# %%
# Print the signal timers on cmd

def printStatus():
    
    
    for i in range(0, noOfSignals):
        if(i == currentGreen):
            if(currentYellow == 0):
                print(" GREEN TS", i+1, "-> r:",
                      signals[i].red, " y:", signals[i].yellow, " g:", signals[i].green)
            else:
                print("YELLOW TS", i+1, "-> r:",
                      signals[i].red, " y:", signals[i].yellow, " g:", signals[i].green)
        else:
            print("   RED TS", i+1, "-> r:",
                  signals[i].red, " y:", signals[i].yellow, " g:", signals[i].green)
    print()

# %%
# Update values of the signal timers after every second

def updateValues():
    
    for i in range(0, noOfSignals):
        if(i == currentGreen):
            if(currentYellow == 0):
                signals[i].green -= 1
                signals[i].totalGreenTime += 1
            else:
                signals[i].yellow -= 1
        else:
            signals[i].red -= 1

# %%
def generateVehicles():
    
    global distribution
    while(True):
        
       
        vehicle_type = random.randint(0, 4)
         
        lane_number = random.randint(0,1)
        
        will_turn = 0
        
        # deciding the direction_number from 
        # a range of values from 1 to 1000
        temp = random.randint(0,999)
        direction_number = 0
        distribution = [500,600,700,1000]
        
        if(temp < distribution[0]):
            direction_number = 0
        elif(temp < distribution[1]):
            direction_number = 1
        elif(temp < distribution[2]):
            direction_number = 2

        # deciding whether the vehicle will turn or not
        if(direction_number==1):
            will_turn = 1
        
        elif((direction_number==0 and lane_number==0) or
            (direction_number==2 and lane_number==1)):
            temp = random.randint(0,5)
            if(temp<3):
                will_turn = 1
            elif(temp<6):
                will_turn = 0
            
        Vehicle(lane_number,vehicleTypes[vehicle_type], direction_number,directionNumbers[direction_number],will_turn)
        
        time.sleep(1)

# %%
def simulationTime():
    
    global timeElapsed, simTime
    while(True):
       
        timeElapsed += 1
        time.sleep(1)
        if(timeElapsed == simTime):
            totalVehicles = 0
            print('Lane-wise Vehicle Counts')
            
            data.append(distribution[0]/1000)
            data.append((distribution[1] - distribution[0])/1000)
            data.append((distribution[2] - distribution[1])/1000)
            data.append((distribution[3] - distribution[2])/1000)
            
            for i in range(noOfSignals):
                print('Lane', i+1, ':',vehicles[directionNumbers[i]]['crossed'])
                totalVehicles += vehicles[directionNumbers[i]]['crossed']
                
            data.append(totalVehicles)

            with open('4-Way-Analysis-Dynamic.csv', 'a', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(data)
                
            print('Total vehicles passed: ', totalVehicles)
            print('Total time passed: ', timeElapsed)
            print('No. of vehicles passed per unit time: ',(float(totalVehicles)/float(timeElapsed)))
            os._exit(1)

# %%
class Main:
    
    thread1 = threading.Thread(
        name="simulationTime", target=simulationTime, args=())
    thread1.daemon = True
    thread1.start()

    thread2 = threading.Thread(
        name="initialization", target=initialize, args=())    # initialization
    thread2.daemon = True
    thread2.start()
    
    # Colours 
    black = (0, 0, 0)
    white = (255, 255, 255)

    # Screensize 
    screenWidth = 1400
    screenHeight = 800
    screenSize = (screenWidth, screenHeight)

    # Setting background image i.e. image of intersection
    background = pygame.image.load('images/intersection/intersection-3-Way.png')

    screen = pygame.display.set_mode(screenSize)
    pygame.display.set_caption("TRAFFIC SIMULATION")

    # Loading signal images and font
    redSignal = pygame.image.load('images/signals/red.png')
    yellowSignal = pygame.image.load('images/signals/yellow.png')
    greenSignal = pygame.image.load('images/signals/green.png')
    font = pygame.font.Font(None, 30)

    thread3 = threading.Thread(
        name="generateVehicles", target=generateVehicles, args=())    # Generating vehicles
    thread3.daemon = True
    thread3.start()
    
    
    
    while True:
        
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                sys.exit()
                
        screen.blit(background,(0,0)) 
        
        for i in range(0,noOfSignals):  # display signal and set timer according to current status: green, yellow, or red
            if(i==currentGreen):
                if(currentYellow==1):
                    if(signals[i].yellow==0):
                        signals[i].signalText = "STOP"
                    else:
                        signals[i].signalText = signals[i].yellow
                    screen.blit(yellowSignal, signalCoods[i])
                else:
                    if(signals[i].green==0):
                        signals[i].signalText = "SLOW"
                    else:
                        signals[i].signalText = signals[i].green
                    screen.blit(greenSignal, signalCoods[i])
            else:
                if(signals[i].red<=15):
                    if(signals[i].red==0):
                        signals[i].signalText = "GO"
                    else:
                        signals[i].signalText = signals[i].red
                else:
                    signals[i].signalText = "---"
                screen.blit(redSignal, signalCoods[i])
        signalTexts = ["","","",""]

        
        for i in range(0,noOfSignals):  
            signalTexts[i] = font.render(str(signals[i].signalText), True, white, black)
            screen.blit(signalTexts[i],signalTimerCoods[i]) 
            displayText = vehicles[directionNumbers[i]]['crossed']
            vehicleCountTexts[i] = font.render(str(displayText), True, black, white)
            screen.blit(vehicleCountTexts[i],vehicleCountCoods[i])
        
        timeElapsedText = font.render(("Time Elapsed: "+str(timeElapsed)), True, black, white)
        screen.blit(timeElapsedText,(1100,50))
        
        for vehicle in simulation:  
            screen.blit(vehicle.currentImage, [vehicle.x, vehicle.y])
            vehicle.move()
        pygame.display.update()
    

Main()
# Out:
#  GREEN TS 1 -> r: 0  y: 5  g: 20
#    RED TS 2 -> r: 25  y: 5  g: 20
#    RED TS 3 -> r: 130  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 19
#    RED TS 2 -> r: 24  y: 5  g: 20
#    RED TS 3 -> r: 129  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 18
#    RED TS 2 -> r: 23  y: 5  g: 20
#    RED TS 3 -> r: 128  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 17
#    RED TS 2 -> r: 22  y: 5  g: 20
#    RED TS 3 -> r: 127  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 16
#    RED TS 2 -> r: 21  y: 5  g: 20
#    RED TS 3 -> r: 126  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 15
#    RED TS 2 -> r: 20  y: 5  g: 20
#    RED TS 3 -> r: 125  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 14
#    RED TS 2 -> r: 19  y: 5  g: 20
#    RED TS 3 -> r: 124  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 13
#    RED TS 2 -> r: 18  y: 5  g: 20
#    RED TS 3 -> r: 123  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 12
#    RED TS 2 -> r: 17  y: 5  g: 20
#    RED TS 3 -> r: 122  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 11
#    RED TS 2 -> r: 16  y: 5  g: 20
#    RED TS 3 -> r: 121  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 10
#    RED TS 2 -> r: 15  y: 5  g: 20
#    RED TS 3 -> r: 120  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 9
#    RED TS 2 -> r: 14  y: 5  g: 20
#    RED TS 3 -> r: 119  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 8
#    RED TS 2 -> r: 13  y: 5  g: 20
#    RED TS 3 -> r: 118  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 7
#    RED TS 2 -> r: 12  y: 5  g: 20
#    RED TS 3 -> r: 117  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 6
#    RED TS 2 -> r: 11  y: 5  g: 20
#    RED TS 3 -> r: 116  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 5
#    RED TS 2 -> r: 10  y: 5  g: 20
#    RED TS 3 -> r: 115  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 4
#    RED TS 2 -> r: 9  y: 5  g: 20
#    RED TS 3 -> r: 114  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 3
#    RED TS 2 -> r: 8  y: 5  g: 20
#    RED TS 3 -> r: 113  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 2
#    RED TS 2 -> r: 7  y: 5  g: 20
#    RED TS 3 -> r: 112  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 1
#    RED TS 2 -> r: 6  y: 5  g: 20
#    RED TS 3 -> r: 111  y: 5  g: 20
#
# Green Time:  1
# YELLOW TS 1 -> r: -50  y: 5  g: 0
#    RED TS 2 -> r: 5  y: 5  g: 10
#    RED TS 3 -> r: 60  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 4  g: 0
#    RED TS 2 -> r: 4  y: 5  g: 10
#    RED TS 3 -> r: 59  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 3  g: 0
#    RED TS 2 -> r: 3  y: 5  g: 10
#    RED TS 3 -> r: 58  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 2  g: 0
#    RED TS 2 -> r: 2  y: 5  g: 10
#    RED TS 3 -> r: 57  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 1  g: 0
#    RED TS 2 -> r: 1  y: 5  g: 10
#    RED TS 3 -> r: 56  y: 5  g: 20
#
#    RED TS 1 -> r: 130  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 10
#    RED TS 3 -> r: 15  y: 5  g: 20
#
#    RED TS 1 -> r: 129  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 9
#    RED TS 3 -> r: 14  y: 5  g: 20
#
#    RED TS 1 -> r: 128  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 8
#    RED TS 3 -> r: 13  y: 5  g: 20
#
#    RED TS 1 -> r: 127  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 7
#    RED TS 3 -> r: 12  y: 5  g: 20
#
#    RED TS 1 -> r: 126  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 6
#    RED TS 3 -> r: 11  y: 5  g: 20
#
#    RED TS 1 -> r: 125  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 5
#    RED TS 3 -> r: 10  y: 5  g: 20
#
#    RED TS 1 -> r: 124  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 4
#    RED TS 3 -> r: 9  y: 5  g: 20
#
#    RED TS 1 -> r: 123  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 3
#    RED TS 3 -> r: 8  y: 5  g: 20
#
#    RED TS 1 -> r: 122  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 2
#    RED TS 3 -> r: 7  y: 5  g: 20
#
#    RED TS 1 -> r: 121  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 1
#    RED TS 3 -> r: 6  y: 5  g: 20
#
# Green Time:  5
#    RED TS 1 -> r: 70  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 5  g: 0
#    RED TS 3 -> r: 5  y: 5  g: 10
#
#    RED TS 1 -> r: 69  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 4  g: 0
#    RED TS 3 -> r: 4  y: 5  g: 10
#
#    RED TS 1 -> r: 68  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 3  g: 0
#    RED TS 3 -> r: 3  y: 5  g: 10
#
#    RED TS 1 -> r: 67  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 2  g: 0
#    RED TS 3 -> r: 2  y: 5  g: 10
#
#    RED TS 1 -> r: 66  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 1  g: 0
#    RED TS 3 -> r: 1  y: 5  g: 10
#
#    RED TS 1 -> r: 15  y: 5  g: 20
#    RED TS 2 -> r: 130  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 10
#
#    RED TS 1 -> r: 14  y: 5  g: 20
#    RED TS 2 -> r: 129  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 9
#
#    RED TS 1 -> r: 13  y: 5  g: 20
#    RED TS 2 -> r: 128  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 8
#
#    RED TS 1 -> r: 12  y: 5  g: 20
#    RED TS 2 -> r: 127  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 7
#
#    RED TS 1 -> r: 11  y: 5  g: 20
#    RED TS 2 -> r: 126  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 6
#
#    RED TS 1 -> r: 10  y: 5  g: 20
#    RED TS 2 -> r: 125  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 5
#
#    RED TS 1 -> r: 9  y: 5  g: 20
#    RED TS 2 -> r: 124  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 4
#
#    RED TS 1 -> r: 8  y: 5  g: 20
#    RED TS 2 -> r: 123  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 3
#
#    RED TS 1 -> r: 7  y: 5  g: 20
#    RED TS 2 -> r: 122  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 2
#
#    RED TS 1 -> r: 6  y: 5  g: 20
#    RED TS 2 -> r: 121  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 1
#
# Green Time:  31
#    RED TS 1 -> r: 5  y: 5  g: 31
#    RED TS 2 -> r: 91  y: 5  g: 20
# YELLOW TS 3 -> r: -29  y: 5  g: 0
#
#    RED TS 1 -> r: 4  y: 5  g: 31
#    RED TS 2 -> r: 90  y: 5  g: 20
# YELLOW TS 3 -> r: -29  y: 4  g: 0
#
#    RED TS 1 -> r: 3  y: 5  g: 31
#    RED TS 2 -> r: 89  y: 5  g: 20
# YELLOW TS 3 -> r: -29  y: 3  g: 0
#
#    RED TS 1 -> r: 2  y: 5  g: 31
#    RED TS 2 -> r: 88  y: 5  g: 20
# YELLOW TS 3 -> r: -29  y: 2  g: 0
#
#    RED TS 1 -> r: 1  y: 5  g: 31
#    RED TS 2 -> r: 87  y: 5  g: 20
# YELLOW TS 3 -> r: -29  y: 1  g: 0
#
#  GREEN TS 1 -> r: 0  y: 5  g: 31
#    RED TS 2 -> r: 36  y: 5  g: 20
#    RED TS 3 -> r: 130  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 30
#    RED TS 2 -> r: 35  y: 5  g: 20
#    RED TS 3 -> r: 129  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 29
#    RED TS 2 -> r: 34  y: 5  g: 20
#    RED TS 3 -> r: 128  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 28
#    RED TS 2 -> r: 33  y: 5  g: 20
#    RED TS 3 -> r: 127  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 27
#    RED TS 2 -> r: 32  y: 5  g: 20
#    RED TS 3 -> r: 126  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 26
#    RED TS 2 -> r: 31  y: 5  g: 20
#    RED TS 3 -> r: 125  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 25
#    RED TS 2 -> r: 30  y: 5  g: 20
#    RED TS 3 -> r: 124  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 24
#    RED TS 2 -> r: 29  y: 5  g: 20
#    RED TS 3 -> r: 123  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 23
#    RED TS 2 -> r: 28  y: 5  g: 20
#    RED TS 3 -> r: 122  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 22
#    RED TS 2 -> r: 27  y: 5  g: 20
#    RED TS 3 -> r: 121  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 21
#    RED TS 2 -> r: 26  y: 5  g: 20
#    RED TS 3 -> r: 120  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 20
#    RED TS 2 -> r: 25  y: 5  g: 20
#    RED TS 3 -> r: 119  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 19
#    RED TS 2 -> r: 24  y: 5  g: 20
#    RED TS 3 -> r: 118  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 18
#    RED TS 2 -> r: 23  y: 5  g: 20
#    RED TS 3 -> r: 117  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 17
#    RED TS 2 -> r: 22  y: 5  g: 20
#    RED TS 3 -> r: 116  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 16
#    RED TS 2 -> r: 21  y: 5  g: 20
#    RED TS 3 -> r: 115  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 15
#    RED TS 2 -> r: 20  y: 5  g: 20
#    RED TS 3 -> r: 114  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 14
#    RED TS 2 -> r: 19  y: 5  g: 20
#    RED TS 3 -> r: 113  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 13
#    RED TS 2 -> r: 18  y: 5  g: 20
#    RED TS 3 -> r: 112  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 12
#    RED TS 2 -> r: 17  y: 5  g: 20
#    RED TS 3 -> r: 111  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 11
#    RED TS 2 -> r: 16  y: 5  g: 20
#    RED TS 3 -> r: 110  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 10
#    RED TS 2 -> r: 15  y: 5  g: 20
#    RED TS 3 -> r: 109  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 9
#    RED TS 2 -> r: 14  y: 5  g: 20
#    RED TS 3 -> r: 108  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 8
#    RED TS 2 -> r: 13  y: 5  g: 20
#    RED TS 3 -> r: 107  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 7
#    RED TS 2 -> r: 12  y: 5  g: 20
#    RED TS 3 -> r: 106  y: 5  g: 20
#  GREEN TS 1 -> r: 0  y: 5  g: 6
#    RED TS 2 -> r: 11  y: 5  g: 20
#    RED TS 3 -> r: 105  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 5
#    RED TS 2 -> r: 10  y: 5  g: 20
#    RED TS 3 -> r: 104  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 4
#    RED TS 2 -> r: 9  y: 5  g: 20
#    RED TS 3 -> r: 103  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 3
#    RED TS 2 -> r: 8  y: 5  g: 20
#    RED TS 3 -> r: 102  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 2
#    RED TS 2 -> r: 7  y: 5  g: 20
#    RED TS 3 -> r: 101  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 1
#    RED TS 2 -> r: 6  y: 5  g: 20
#    RED TS 3 -> r: 100  y: 5  g: 20
#
# Green Time:  8
# YELLOW TS 1 -> r: -50  y: 5  g: 0
#    RED TS 2 -> r: 5  y: 5  g: 10
#    RED TS 3 -> r: 49  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 4  g: 0
#    RED TS 2 -> r: 4  y: 5  g: 10
#    RED TS 3 -> r: 48  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 3  g: 0
#    RED TS 2 -> r: 3  y: 5  g: 10
#    RED TS 3 -> r: 47  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 2  g: 0
#    RED TS 2 -> r: 2  y: 5  g: 10
#    RED TS 3 -> r: 46  y: 5  g: 20
#
# YELLOW TS 1 -> r: -50  y: 1  g: 0
#    RED TS 2 -> r: 1  y: 5  g: 10
#    RED TS 3 -> r: 45  y: 5  g: 20
#
#    RED TS 1 -> r: 130  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 10
#    RED TS 3 -> r: 15  y: 5  g: 20
#
#    RED TS 1 -> r: 129  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 9
#    RED TS 3 -> r: 14  y: 5  g: 20
#
#    RED TS 1 -> r: 128  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 8
#    RED TS 3 -> r: 13  y: 5  g: 20
#
#    RED TS 1 -> r: 127  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 7
#    RED TS 3 -> r: 12  y: 5  g: 20
#
#    RED TS 1 -> r: 126  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 6
#    RED TS 3 -> r: 11  y: 5  g: 20
#
#    RED TS 1 -> r: 125  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 5
#    RED TS 3 -> r: 10  y: 5  g: 20
#
#    RED TS 1 -> r: 124  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 4
#    RED TS 3 -> r: 9  y: 5  g: 20
#
#    RED TS 1 -> r: 123  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 3
#    RED TS 3 -> r: 8  y: 5  g: 20
#
#    RED TS 1 -> r: 122  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 2
#    RED TS 3 -> r: 7  y: 5  g: 20
#
#    RED TS 1 -> r: 121  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 1
#    RED TS 3 -> r: 6  y: 5  g: 20
#
# Green Time:  5
#    RED TS 1 -> r: 70  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 5  g: 0
#    RED TS 3 -> r: 5  y: 5  g: 10
#
#    RED TS 1 -> r: 69  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 4  g: 0
#    RED TS 3 -> r: 4  y: 5  g: 10
#
#    RED TS 1 -> r: 68  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 3  g: 0
#    RED TS 3 -> r: 3  y: 5  g: 10
#
#    RED TS 1 -> r: 67  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 2  g: 0
#    RED TS 3 -> r: 2  y: 5  g: 10
#
#    RED TS 1 -> r: 66  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 1  g: 0
#    RED TS 3 -> r: 1  y: 5  g: 10
#
#    RED TS 1 -> r: 15  y: 5  g: 20
#    RED TS 2 -> r: 130  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 10
#
#    RED TS 1 -> r: 14  y: 5  g: 20
#    RED TS 2 -> r: 129  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 9
#
#    RED TS 1 -> r: 13  y: 5  g: 20
#    RED TS 2 -> r: 128  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 8
#
#    RED TS 1 -> r: 12  y: 5  g: 20
#    RED TS 2 -> r: 127  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 7
#
#    RED TS 1 -> r: 11  y: 5  g: 20
#    RED TS 2 -> r: 126  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 6
#
#    RED TS 1 -> r: 10  y: 5  g: 20
#    RED TS 2 -> r: 125  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 5
#
#    RED TS 1 -> r: 9  y: 5  g: 20
#    RED TS 2 -> r: 124  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 4
#
#    RED TS 1 -> r: 8  y: 5  g: 20
#    RED TS 2 -> r: 123  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 3
#
#    RED TS 1 -> r: 7  y: 5  g: 20
#    RED TS 2 -> r: 122  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 2
#
#    RED TS 1 -> r: 6  y: 5  g: 20
#    RED TS 2 -> r: 121  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 1
#
# Green Time:  46
#    RED TS 1 -> r: 5  y: 5  g: 46
#    RED TS 2 -> r: 106  y: 5  g: 20
# YELLOW TS 3 -> r: -14  y: 5  g: 0
#
#    RED TS 1 -> r: 4  y: 5  g: 46
#    RED TS 2 -> r: 105  y: 5  g: 20
# YELLOW TS 3 -> r: -14  y: 4  g: 0
#
#    RED TS 1 -> r: 3  y: 5  g: 46
#    RED TS 2 -> r: 104  y: 5  g: 20
# YELLOW TS 3 -> r: -14  y: 3  g: 0
#
#    RED TS 1 -> r: 2  y: 5  g: 46
#    RED TS 2 -> r: 103  y: 5  g: 20
# YELLOW TS 3 -> r: -14  y: 2  g: 0
#
#    RED TS 1 -> r: 1  y: 5  g: 46
#    RED TS 2 -> r: 102  y: 5  g: 20
# YELLOW TS 3 -> r: -14  y: 1  g: 0
#
#  GREEN TS 1 -> r: 0  y: 5  g: 46
#    RED TS 2 -> r: 51  y: 5  g: 20
#    RED TS 3 -> r: 130  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 45
#    RED TS 2 -> r: 50  y: 5  g: 20
#    RED TS 3 -> r: 129  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 44
#    RED TS 2 -> r: 49  y: 5  g: 20
#    RED TS 3 -> r: 128  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 43
#    RED TS 2 -> r: 48  y: 5  g: 20
#    RED TS 3 -> r: 127  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 42
#    RED TS 2 -> r: 47  y: 5  g: 20
#    RED TS 3 -> r: 126  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 41
#    RED TS 2 -> r: 46  y: 5  g: 20
#    RED TS 3 -> r: 125  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 40
#    RED TS 2 -> r: 45  y: 5  g: 20
#    RED TS 3 -> r: 124  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 39
#    RED TS 2 -> r: 44  y: 5  g: 20
#    RED TS 3 -> r: 123  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 38
#    RED TS 2 -> r: 43  y: 5  g: 20
#    RED TS 3 -> r: 122  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 37
#    RED TS 2 -> r: 42  y: 5  g: 20
#    RED TS 3 -> r: 121  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 36
#    RED TS 2 -> r: 41  y: 5  g: 20
#    RED TS 3 -> r: 120  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 35
#    RED TS 2 -> r: 40  y: 5  g: 20
#    RED TS 3 -> r: 119  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 34
#    RED TS 2 -> r: 39  y: 5  g: 20
#    RED TS 3 -> r: 118  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 33
#    RED TS 2 -> r: 38  y: 5  g: 20
#    RED TS 3 -> r: 117  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 32
#    RED TS 2 -> r: 37  y: 5  g: 20
#    RED TS 3 -> r: 116  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 31
#    RED TS 2 -> r: 36  y: 5  g: 20
#    RED TS 3 -> r: 115  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 30
#    RED TS 2 -> r: 35  y: 5  g: 20
#    RED TS 3 -> r: 114  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 29
#    RED TS 2 -> r: 34  y: 5  g: 20
#    RED TS 3 -> r: 113  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 28
#    RED TS 2 -> r: 33  y: 5  g: 20
#    RED TS 3 -> r: 112  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 27
#    RED TS 2 -> r: 32  y: 5  g: 20
#    RED TS 3 -> r: 111  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 26
#    RED TS 2 -> r: 31  y: 5  g: 20
#    RED TS 3 -> r: 110  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 25
#    RED TS 2 -> r: 30  y: 5  g: 20
#    RED TS 3 -> r: 109  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 24
#    RED TS 2 -> r: 29  y: 5  g: 20
#    RED TS 3 -> r: 108  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 23
#    RED TS 2 -> r: 28  y: 5  g: 20
#    RED TS 3 -> r: 107  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 22
#    RED TS 2 -> r: 27  y: 5  g: 20
#    RED TS 3 -> r: 106  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 21
#    RED TS 2 -> r: 26  y: 5  g: 20
#    RED TS 3 -> r: 105  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 20
#    RED TS 2 -> r: 25  y: 5  g: 20
#    RED TS 3 -> r: 104  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 19
#    RED TS 2 -> r: 24  y: 5  g: 20
#    RED TS 3 -> r: 103  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 18
#    RED TS 2 -> r: 23  y: 5  g: 20
#    RED TS 3 -> r: 102  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 17
#    RED TS 2 -> r: 22  y: 5  g: 20
#    RED TS 3 -> r: 101  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 16
#    RED TS 2 -> r: 21  y: 5  g: 20
#    RED TS 3 -> r: 100  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 15
#    RED TS 2 -> r: 20  y: 5  g: 20
#    RED TS 3 -> r: 99  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 14
#    RED TS 2 -> r: 19  y: 5  g: 20
#    RED TS 3 -> r: 98  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 13
#    RED TS 2 -> r: 18  y: 5  g: 20
#    RED TS 3 -> r: 97  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 12
#    RED TS 2 -> r: 17  y: 5  g: 20
#    RED TS 3 -> r: 96  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 11
#    RED TS 2 -> r: 16  y: 5  g: 20
#    RED TS 3 -> r: 95  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 10
#    RED TS 2 -> r: 15  y: 5  g: 20
#    RED TS 3 -> r: 94  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 9
#    RED TS 2 -> r: 14  y: 5  g: 20
#    RED TS 3 -> r: 93  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 8
#    RED TS 2 -> r: 13  y: 5  g: 20
#    RED TS 3 -> r: 92  y: 5  g: 20
#  GREEN TS 1 -> r: 0  y: 5  g: 7
#    RED TS 2 -> r: 12  y: 5  g: 20
#    RED TS 3 -> r: 91  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 6
#    RED TS 2 -> r: 11  y: 5  g: 20
#    RED TS 3 -> r: 90  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 5
#    RED TS 2 -> r: 10  y: 5  g: 20
#    RED TS 3 -> r: 89  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 4
#    RED TS 2 -> r: 9  y: 5  g: 20
#    RED TS 3 -> r: 88  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 3
#    RED TS 2 -> r: 8  y: 5  g: 20
#    RED TS 3 -> r: 87  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 2
#    RED TS 2 -> r: 7  y: 5  g: 20
#    RED TS 3 -> r: 86  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 1
#    RED TS 2 -> r: 6  y: 5  g: 20
#    RED TS 3 -> r: 85  y: 5  g: 20
#
# Green Time:  12
# YELLOW TS 1 -> r: -48  y: 5  g: 0
#    RED TS 2 -> r: 5  y: 5  g: 12
#    RED TS 3 -> r: 36  y: 5  g: 20
#
# YELLOW TS 1 -> r: -48  y: 4  g: 0
#    RED TS 2 -> r: 4  y: 5  g: 12
#    RED TS 3 -> r: 35  y: 5  g: 20
#
# YELLOW TS 1 -> r: -48  y: 3  g: 0
#    RED TS 2 -> r: 3  y: 5  g: 12
#    RED TS 3 -> r: 34  y: 5  g: 20
#
# YELLOW TS 1 -> r: -48  y: 2  g: 0
#    RED TS 2 -> r: 2  y: 5  g: 12
#    RED TS 3 -> r: 33  y: 5  g: 20
#
# YELLOW TS 1 -> r: -48  y: 1  g: 0
#    RED TS 2 -> r: 1  y: 5  g: 12
#    RED TS 3 -> r: 32  y: 5  g: 20
#
#    RED TS 1 -> r: 130  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 12
#    RED TS 3 -> r: 17  y: 5  g: 20
#
#    RED TS 1 -> r: 129  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 11
#    RED TS 3 -> r: 16  y: 5  g: 20
#
#    RED TS 1 -> r: 128  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 10
#    RED TS 3 -> r: 15  y: 5  g: 20
#
#    RED TS 1 -> r: 127  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 9
#    RED TS 3 -> r: 14  y: 5  g: 20
#
#    RED TS 1 -> r: 126  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 8
#    RED TS 3 -> r: 13  y: 5  g: 20
#
#    RED TS 1 -> r: 125  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 7
#    RED TS 3 -> r: 12  y: 5  g: 20
#
#    RED TS 1 -> r: 124  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 6
#    RED TS 3 -> r: 11  y: 5  g: 20
#
#    RED TS 1 -> r: 123  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 5
#    RED TS 3 -> r: 10  y: 5  g: 20
#
#    RED TS 1 -> r: 122  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 4
#    RED TS 3 -> r: 9  y: 5  g: 20
#
#    RED TS 1 -> r: 121  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 3
#    RED TS 3 -> r: 8  y: 5  g: 20
#
#    RED TS 1 -> r: 120  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 2
#    RED TS 3 -> r: 7  y: 5  g: 20
#
#    RED TS 1 -> r: 119  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 1
#    RED TS 3 -> r: 6  y: 5  g: 20
#
# Green Time:  11
#    RED TS 1 -> r: 69  y: 5  g: 20
# YELLOW TS 2 -> r: -49  y: 5  g: 0
#    RED TS 3 -> r: 5  y: 5  g: 11
#
#    RED TS 1 -> r: 68  y: 5  g: 20
# YELLOW TS 2 -> r: -49  y: 4  g: 0
#    RED TS 3 -> r: 4  y: 5  g: 11
#
#    RED TS 1 -> r: 67  y: 5  g: 20
# YELLOW TS 2 -> r: -49  y: 3  g: 0
#    RED TS 3 -> r: 3  y: 5  g: 11
#
#    RED TS 1 -> r: 66  y: 5  g: 20
# YELLOW TS 2 -> r: -49  y: 2  g: 0
#    RED TS 3 -> r: 2  y: 5  g: 11
#
#    RED TS 1 -> r: 65  y: 5  g: 20
# YELLOW TS 2 -> r: -49  y: 1  g: 0
#    RED TS 3 -> r: 1  y: 5  g: 11
#
#    RED TS 1 -> r: 16  y: 5  g: 20
#    RED TS 2 -> r: 130  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 11
#
#    RED TS 1 -> r: 15  y: 5  g: 20
#    RED TS 2 -> r: 129  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 10
#
#    RED TS 1 -> r: 14  y: 5  g: 20
#    RED TS 2 -> r: 128  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 9
#
#    RED TS 1 -> r: 13  y: 5  g: 20
#    RED TS 2 -> r: 127  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 8
#
#    RED TS 1 -> r: 12  y: 5  g: 20
#    RED TS 2 -> r: 126  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 7
#
#    RED TS 1 -> r: 11  y: 5  g: 20
#    RED TS 2 -> r: 125  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 6
#
#    RED TS 1 -> r: 10  y: 5  g: 20
#    RED TS 2 -> r: 124  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 5
#
#    RED TS 1 -> r: 9  y: 5  g: 20
#    RED TS 2 -> r: 123  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 4
#
#    RED TS 1 -> r: 8  y: 5  g: 20
#    RED TS 2 -> r: 122  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 3
#
#    RED TS 1 -> r: 7  y: 5  g: 20
#    RED TS 2 -> r: 121  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 2
#
#    RED TS 1 -> r: 6  y: 5  g: 20
#    RED TS 2 -> r: 120  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 1
#
# Green Time:  63
#    RED TS 1 -> r: 5  y: 5  g: 60
#    RED TS 2 -> r: 119  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 5  g: 0
#
#    RED TS 1 -> r: 4  y: 5  g: 60
#    RED TS 2 -> r: 118  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 4  g: 0
#
#    RED TS 1 -> r: 3  y: 5  g: 60
#    RED TS 2 -> r: 117  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 3  g: 0
#
#    RED TS 1 -> r: 2  y: 5  g: 60
#    RED TS 2 -> r: 116  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 2  g: 0
#
#    RED TS 1 -> r: 1  y: 5  g: 60
#    RED TS 2 -> r: 115  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 1  g: 0
#
#  GREEN TS 1 -> r: 0  y: 5  g: 60
#    RED TS 2 -> r: 65  y: 5  g: 20
#    RED TS 3 -> r: 130  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 59
#    RED TS 2 -> r: 64  y: 5  g: 20
#    RED TS 3 -> r: 129  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 58
#    RED TS 2 -> r: 63  y: 5  g: 20
#    RED TS 3 -> r: 128  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 57
#    RED TS 2 -> r: 62  y: 5  g: 20
#    RED TS 3 -> r: 127  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 56
#    RED TS 2 -> r: 61  y: 5  g: 20
#    RED TS 3 -> r: 126  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 55
#    RED TS 2 -> r: 60  y: 5  g: 20
#    RED TS 3 -> r: 125  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 54
#    RED TS 2 -> r: 59  y: 5  g: 20
#    RED TS 3 -> r: 124  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 53
#    RED TS 2 -> r: 58  y: 5  g: 20
#    RED TS 3 -> r: 123  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 52
#    RED TS 2 -> r: 57  y: 5  g: 20
#    RED TS 3 -> r: 122  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 51
#    RED TS 2 -> r: 56  y: 5  g: 20
#    RED TS 3 -> r: 121  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 50
#    RED TS 2 -> r: 55  y: 5  g: 20
#    RED TS 3 -> r: 120  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 49
#    RED TS 2 -> r: 54  y: 5  g: 20
#    RED TS 3 -> r: 119  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 48
#    RED TS 2 -> r: 53  y: 5  g: 20
#    RED TS 3 -> r: 118  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 47
#    RED TS 2 -> r: 52  y: 5  g: 20
#    RED TS 3 -> r: 117  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 46
#    RED TS 2 -> r: 51  y: 5  g: 20
#    RED TS 3 -> r: 116  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 45
#    RED TS 2 -> r: 50  y: 5  g: 20
#    RED TS 3 -> r: 115  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 44
#    RED TS 2 -> r: 49  y: 5  g: 20
#    RED TS 3 -> r: 114  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 43
#    RED TS 2 -> r: 48  y: 5  g: 20
#    RED TS 3 -> r: 113  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 42
#    RED TS 2 -> r: 47  y: 5  g: 20
#    RED TS 3 -> r: 112  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 41
#    RED TS 2 -> r: 46  y: 5  g: 20
#    RED TS 3 -> r: 111  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 40
#    RED TS 2 -> r: 45  y: 5  g: 20
#    RED TS 3 -> r: 110  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 39
#    RED TS 2 -> r: 44  y: 5  g: 20
#    RED TS 3 -> r: 109  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 38
#    RED TS 2 -> r: 43  y: 5  g: 20
#    RED TS 3 -> r: 108  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 37
#    RED TS 2 -> r: 42  y: 5  g: 20
#    RED TS 3 -> r: 107  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 36
#    RED TS 2 -> r: 41  y: 5  g: 20
#    RED TS 3 -> r: 106  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 35
#    RED TS 2 -> r: 40  y: 5  g: 20
#    RED TS 3 -> r: 105  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 34
#    RED TS 2 -> r: 39  y: 5  g: 20
#    RED TS 3 -> r: 104  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 33
#    RED TS 2 -> r: 38  y: 5  g: 20
#    RED TS 3 -> r: 103  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 32
#    RED TS 2 -> r: 37  y: 5  g: 20
#    RED TS 3 -> r: 102  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 31
#    RED TS 2 -> r: 36  y: 5  g: 20
#    RED TS 3 -> r: 101  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 30
#    RED TS 2 -> r: 35  y: 5  g: 20
#    RED TS 3 -> r: 100  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 29
#    RED TS 2 -> r: 34  y: 5  g: 20
#    RED TS 3 -> r: 99  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 28
#    RED TS 2 -> r: 33  y: 5  g: 20
#    RED TS 3 -> r: 98  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 27
#    RED TS 2 -> r: 32  y: 5  g: 20
#    RED TS 3 -> r: 97  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 26
#    RED TS 2 -> r: 31  y: 5  g: 20
#    RED TS 3 -> r: 96  y: 5  g: 20
#  GREEN TS 1 -> r: 0  y: 5  g: 25
#    RED TS 2 -> r: 30  y: 5  g: 20
#    RED TS 3 -> r: 95  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 24
#    RED TS 2 -> r: 29  y: 5  g: 20
#    RED TS 3 -> r: 94  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 23
#    RED TS 2 -> r: 28  y: 5  g: 20
#    RED TS 3 -> r: 93  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 22
#    RED TS 2 -> r: 27  y: 5  g: 20
#    RED TS 3 -> r: 92  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 21
#    RED TS 2 -> r: 26  y: 5  g: 20
#    RED TS 3 -> r: 91  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 20
#    RED TS 2 -> r: 25  y: 5  g: 20
#    RED TS 3 -> r: 90  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 19
#    RED TS 2 -> r: 24  y: 5  g: 20
#    RED TS 3 -> r: 89  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 18
#    RED TS 2 -> r: 23  y: 5  g: 20
#    RED TS 3 -> r: 88  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 17
#    RED TS 2 -> r: 22  y: 5  g: 20
#    RED TS 3 -> r: 87  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 16
#    RED TS 2 -> r: 21  y: 5  g: 20
#    RED TS 3 -> r: 86  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 15
#    RED TS 2 -> r: 20  y: 5  g: 20
#    RED TS 3 -> r: 85  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 14
#    RED TS 2 -> r: 19  y: 5  g: 20
#    RED TS 3 -> r: 84  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 13
#    RED TS 2 -> r: 18  y: 5  g: 20
#    RED TS 3 -> r: 83  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 12
#    RED TS 2 -> r: 17  y: 5  g: 20
#    RED TS 3 -> r: 82  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 11
#    RED TS 2 -> r: 16  y: 5  g: 20
#    RED TS 3 -> r: 81  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 10
#    RED TS 2 -> r: 15  y: 5  g: 20
#    RED TS 3 -> r: 80  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 9
#    RED TS 2 -> r: 14  y: 5  g: 20
#    RED TS 3 -> r: 79  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 8
#    RED TS 2 -> r: 13  y: 5  g: 20
#    RED TS 3 -> r: 78  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 7
#    RED TS 2 -> r: 12  y: 5  g: 20
#    RED TS 3 -> r: 77  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 6
#    RED TS 2 -> r: 11  y: 5  g: 20
#    RED TS 3 -> r: 76  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 5
#    RED TS 2 -> r: 10  y: 5  g: 20
#    RED TS 3 -> r: 75  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 4
#    RED TS 2 -> r: 9  y: 5  g: 20
#    RED TS 3 -> r: 74  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 3
#    RED TS 2 -> r: 8  y: 5  g: 20
#    RED TS 3 -> r: 73  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 2
#    RED TS 2 -> r: 7  y: 5  g: 20
#    RED TS 3 -> r: 72  y: 5  g: 20
#
#  GREEN TS 1 -> r: 0  y: 5  g: 1
#    RED TS 2 -> r: 6  y: 5  g: 20
#    RED TS 3 -> r: 71  y: 5  g: 20
#
# Green Time:  11
# YELLOW TS 1 -> r: -49  y: 5  g: 0
#    RED TS 2 -> r: 5  y: 5  g: 11
#    RED TS 3 -> r: 21  y: 5  g: 20
#
# YELLOW TS 1 -> r: -49  y: 4  g: 0
#    RED TS 2 -> r: 4  y: 5  g: 11
#    RED TS 3 -> r: 20  y: 5  g: 20
#
# YELLOW TS 1 -> r: -49  y: 3  g: 0
#    RED TS 2 -> r: 3  y: 5  g: 11
#    RED TS 3 -> r: 19  y: 5  g: 20
#
# YELLOW TS 1 -> r: -49  y: 2  g: 0
#    RED TS 2 -> r: 2  y: 5  g: 11
#    RED TS 3 -> r: 18  y: 5  g: 20
#
# YELLOW TS 1 -> r: -49  y: 1  g: 0
#    RED TS 2 -> r: 1  y: 5  g: 11
#    RED TS 3 -> r: 17  y: 5  g: 20
#
#    RED TS 1 -> r: 130  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 11
#    RED TS 3 -> r: 16  y: 5  g: 20
#
#    RED TS 1 -> r: 129  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 10
#    RED TS 3 -> r: 15  y: 5  g: 20
#
#    RED TS 1 -> r: 128  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 9
#    RED TS 3 -> r: 14  y: 5  g: 20
#
#    RED TS 1 -> r: 127  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 8
#    RED TS 3 -> r: 13  y: 5  g: 20
#
#    RED TS 1 -> r: 126  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 7
#    RED TS 3 -> r: 12  y: 5  g: 20
#
#    RED TS 1 -> r: 125  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 6
#    RED TS 3 -> r: 11  y: 5  g: 20
#
#    RED TS 1 -> r: 124  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 5
#    RED TS 3 -> r: 10  y: 5  g: 20
#
#    RED TS 1 -> r: 123  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 4
#    RED TS 3 -> r: 9  y: 5  g: 20
#
#    RED TS 1 -> r: 122  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 3
#    RED TS 3 -> r: 8  y: 5  g: 20
#
#    RED TS 1 -> r: 121  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 2
#    RED TS 3 -> r: 7  y: 5  g: 20
#
#    RED TS 1 -> r: 120  y: 5  g: 20
#  GREEN TS 2 -> r: 0  y: 5  g: 1
#    RED TS 3 -> r: 6  y: 5  g: 20
#
# Green Time:  4
#    RED TS 1 -> r: 69  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 5  g: 0
#    RED TS 3 -> r: 5  y: 5  g: 10
#
#    RED TS 1 -> r: 68  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 4  g: 0
#    RED TS 3 -> r: 4  y: 5  g: 10
#
#    RED TS 1 -> r: 67  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 3  g: 0
#    RED TS 3 -> r: 3  y: 5  g: 10
#
#    RED TS 1 -> r: 66  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 2  g: 0
#    RED TS 3 -> r: 2  y: 5  g: 10
#
#    RED TS 1 -> r: 65  y: 5  g: 20
# YELLOW TS 2 -> r: -50  y: 1  g: 0
#    RED TS 3 -> r: 1  y: 5  g: 10
#
#    RED TS 1 -> r: 15  y: 5  g: 20
#    RED TS 2 -> r: 130  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 10
#
#    RED TS 1 -> r: 14  y: 5  g: 20
#    RED TS 2 -> r: 129  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 9
#
#    RED TS 1 -> r: 13  y: 5  g: 20
#    RED TS 2 -> r: 128  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 8
#
#    RED TS 1 -> r: 12  y: 5  g: 20
#    RED TS 2 -> r: 127  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 7
#
#    RED TS 1 -> r: 11  y: 5  g: 20
#    RED TS 2 -> r: 126  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 6
#
#    RED TS 1 -> r: 10  y: 5  g: 20
#    RED TS 2 -> r: 125  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 5
#
#    RED TS 1 -> r: 9  y: 5  g: 20
#    RED TS 2 -> r: 124  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 4
#
#    RED TS 1 -> r: 8  y: 5  g: 20
#    RED TS 2 -> r: 123  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 3
#
#    RED TS 1 -> r: 7  y: 5  g: 20
#    RED TS 2 -> r: 122  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 2
#
#    RED TS 1 -> r: 6  y: 5  g: 20
#    RED TS 2 -> r: 121  y: 5  g: 20
#  GREEN TS 3 -> r: 0  y: 5  g: 1
#
# Green Time:  90
#    RED TS 1 -> r: 5  y: 5  g: 60
#    RED TS 2 -> r: 120  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 5  g: 0
#
#    RED TS 1 -> r: 4  y: 5  g: 60
#    RED TS 2 -> r: 119  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 4  g: 0
#
#    RED TS 1 -> r: 3  y: 5  g: 60
#    RED TS 2 -> r: 118  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 3  g: 0
#
#    RED TS 1 -> r: 2  y: 5  g: 60
#    RED TS 2 -> r: 117  y: 5  g: 20
# YELLOW TS 3 -> r: 0  y: 2  g: 0
